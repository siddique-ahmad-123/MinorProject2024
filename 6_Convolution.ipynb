# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import argmax, sqrt, mean, absolute, linspace, log10, logical_and, average, diff, correlate

fs=100
# Parameters for the rectangular signals
start1, end1 = 10, 30
height1 = 1
length1 = 100

start2, end2 = 40, 60
height2 = 0.5
length2 = 100

# Create rectangular signals
#rect_signal1 = rectangular_signal(start1, end1, height1, length1)
#rect_signal2 = rectangular_signal(start2, end2, height2, length2)

excel_file_path = 'sinwave_snr10dB_2Hz_Fs100Hz.xlsx'
df = pd.read_excel(excel_file_path)
rect_signal1 = df['amplitude'].values

excel_file_path = 'sinwave_snr10dB_2Hz_Fs100Hz.xlsx'
df = pd.read_excel(excel_file_path)
rect_signal2 = df['amplitude'].values


# Perform convolution
convolution_result = np.convolve(rect_signal1, rect_signal2, mode='full')

# Plot the signals
plt.figure(figsize=(12, 6))

plt.subplot(3, 1, 1)
plt.plot(rect_signal1, label='Rectangular Signal 1')
plt.title('Rectangular Signal 1')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(rect_signal2, label='Rectangular Signal 2')
plt.title('Rectangular Signal 2')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()

# Plot the convolution result
plt.subplot(3, 1, 3)
plt.plot(convolution_result, label='Convolution Result')
plt.title('Convolution Result')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 0.19040675438539623
