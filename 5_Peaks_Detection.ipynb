# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

fs=100
# Example usage:
excel_file_path = 'decay_sinwave_snr10dB_2Hz_Fs100Hz.xlsx'
df = pd.read_excel(excel_file_path)

plt.plot(df);
amp = df['amplitude'].values
peaks, _ = find_peaks(amp)
print(peaks);
print(amp[peaks]);
#plt.plot(amp[peaks]);
# Out:
# [ 12  62 112 162 212 262 312 362 412 462]
# [0.93991025 0.73200186 0.57007637 0.44398005 0.34576989 0.26928437
#  0.2097204  0.16333339 0.12720236 0.09905845]
